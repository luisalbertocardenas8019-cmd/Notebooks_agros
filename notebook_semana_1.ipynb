# %% [markdown]
# <a href="https://colab.research.google.com/github/luisalbertocardenas8019-cmd/Notebooks_agros/blob/main/notebook_semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ancho = 1
alto = 2

lm = 2 * (ancho + alto)
av = 2 * (ancho + alto)

print (lm)
print (av)
# Out:
# 6
# 6
